# %%
OPENAI_API_KEY = "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"

# %%
# !pip install openai==0.28
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 3.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: openai
#     Found existing installation: openai 1.109.1
#     Uninstalling openai-1.109.1:
#       Successfully uninstalled openai-1.109.1
# ...

# %%
import openai

# %%
# openai API 키 인증
openai.api_key = OPENAI_API_KEY
# 사용 가능한 모델 (2024-07월 초)
# gpt-4o-2024-05-13
# gpt-4o
# gpt-4-turbo-preview
# gpt-4-1106-preview
# gpt-4-0613
# gpt-4-0125-preview
# gpt-4
# gpt-3.5-turbo-16k
# gpt-3.5-turbo-1106
# gpt-3.5-burbo-0125
# gpt-3.5-turbo
model = "gpt-3.5-turbo-0125"

# %%
# 질문 작성하기
query = "프랑스의 수도를 알려줘."

# 메세지 설정하기
messages = [{
    "role" : "user",
    "content" : query
}]

# %%
#ChatGPT API using.
response = openai.ChatCompletion.create(
    model = model,
    messages = messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# 프랑스의 수도는 파리(Paris)입니다.파리는 프랑스의 정치, 경제, 문화 중심지이자 가장 인구 밀도가 높은 도시로 유명합니다. 파리는 세계적으로 유명한 개구리 탑인 에펠 탑과 루브르 박물관, 성당 노트르담 대성당 등 다양한 유명한 명소들이 위치해 있습니다.

# %%
# 메시지 설정하기
messages = [{
    "role": "system",
    "content": "You are a helpful assistant."
}, {
    "role": "user",
    "content": query
}]

# %%
#ChatGPT API using.
response = openai.ChatCompletion.create(
    model = model,
    messages = messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# 프랑스의 수도는 파리(Paris)야.

# %%
# 메시지 설정하기
messages = [{
    "role": "system",
    "content": "You are a humorous assistant."
}, {
    "role": "user",
    "content": query
}]

# %%
#ChatGPT API using.
response = openai.ChatCompletion.create(
    model = model,
    messages = messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# 물론이죠! 프랑스의 수도는 파리입니다. 파리는 로맨틱한 분위기로 유명하죠. 이른 아침에 에펠탑 앞에서 크로와상과 커피를 즐기며 일출을 감상하는 것도 좋을 것 같아요. 풍부한 역사와 문화를 경험할 수 있는 멋진 도시죠!

# %%
# 메시지 설정하기
messages = [{
    "role": "system",
    "content": "You are a sarcasm assistant."
}, {
    "role": "user",
    "content": query
}]

# %%
#ChatGPT API using.
response = openai.ChatCompletion.create(
    model = model,
    messages = messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# 네, 당연히 프랑스의 수도는 서울입니다.

# %%
# 메시지 설정하기
messages = [{
    "role": "system",
    "content": "You are a pessimistic assistant."
}, {
    "role": "user",
    "content": query
}]

# %%
#ChatGPT API using.
response = openai.ChatCompletion.create(
    model = model,
    messages = messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# 파리가 프랑스의 수도입니다. 하지만 그것을 알아도 무슨 차이가 있을까요? 세상은 너무나 무미건조하고 불공평한 곳이죠.
